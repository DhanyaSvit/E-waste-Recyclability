# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('e_waste_dataset_with_profit.csv')
df.head()

# %%
df.shape

# %%
df.dtypes

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %%
df.drop_duplicates(inplace=True)
df.shape

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(r'[\s\(\)\$]+', '_', regex=True)
    .str.replace(r'_+', '_', regex=True)
    .str.strip('_')
)
df.columns

# %%
df['item'] = df['item'].str.strip().str.title()
df['category'] = df['category'].str.strip()
df[['item', 'category']].head(10)

# %%
df['category'].unique()

# %%
category_map = {
    'Cat1': 'Small Appliances',
    'Cat2': 'Large Appliances',
    'Cat3': 'Consumer Electronics',
    'Cat4': 'Audio and Visual'
}

df['category'] = df['category'].map(category_map)
df['category'].unique()

# %%
df['item'] = df['item'].astype('category')
df['category'] = df['category'].astype('category')
df.dtypes

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns

for col in numeric_cols:
    missing = df[col].isnull().sum()
    if missing > 0:
        df[col].fillna(df[col].median(), inplace=True)

df.isnull().sum()

# %%
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    df[col] = df[col].clip(lower=lower, upper=upper)

df.describe()

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %%
df.dtypes

# %%
df.head(10)

# %%
df.to_csv('e_waste_cleaned.csv', index=False)
print('Saved to e_waste_cleaned.csv')
