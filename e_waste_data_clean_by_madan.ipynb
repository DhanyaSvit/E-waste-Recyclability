# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a7152c09-d420-4a8e-b2cf-19f7fce04f84" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a7152c09-d420-4a8e-b2cf-19f7fce04f84">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("cleaned_ewaste_dataset.csv")

df.head()
# Out:
#               Item Category  Gold  Silver  Platinum  Rhodium  Nickel   Tin  \
# 0        iPhone 11     Cat3  3.58    2.95      1.73     8.92    1.91  1.01
# 1          Toaster     Cat2  7.21    4.31      6.21     5.63    9.59  7.65
# 2          Speaker     Cat4  8.91    5.09      2.42     7.70    1.09  1.49
# 3   Microwave Oven     Cat2  2.62    3.84      2.98     7.66    9.41  2.25
# 4  Air Conditioner     Cat1  3.47    3.89      6.20     4.35    5.07  8.65
#
#    Lithium  Aluminum  Carbon  Profit ($)
# 0     1.82      1.27    9.51         270
# 1     0.51      3.03    4.22         689
# 2     7.42      3.63    8.83         570
# 3     7.84      6.18    6.36         290
# 4     8.62      0.82    5.53         505

# %%
df.shape
# Out:
# (10000, 12)

# %%
df.columns
# Out:
# Index(['Item', 'Category', 'Gold', 'Silver', 'Platinum', 'Rhodium', 'Nickel',
#        'Tin', 'Lithium', 'Aluminum', 'Carbon', 'Profit ($)'],
#       dtype='object')

# %%
df.head()
# Out:
#               Item Category  Gold  Silver  Platinum  Rhodium  Nickel   Tin  \
# 0        iPhone 11     Cat3  3.58    2.95      1.73     8.92    1.91  1.01
# 1          Toaster     Cat2  7.21    4.31      6.21     5.63    9.59  7.65
# 2          Speaker     Cat4  8.91    5.09      2.42     7.70    1.09  1.49
# 3   Microwave Oven     Cat2  2.62    3.84      2.98     7.66    9.41  2.25
# 4  Air Conditioner     Cat1  3.47    3.89      6.20     4.35    5.07  8.65
#
#    Lithium  Aluminum  Carbon  Profit ($)
# 0     1.82      1.27    9.51         270
# 1     0.51      3.03    4.22         689
# 2     7.42      3.63    8.83         570
# 3     7.84      6.18    6.36         290
# 4     8.62      0.82    5.53         505

# %%
df.isnull().sum()
# Out:
# Item          0
# Category      0
# Gold          0
# Silver        0
# Platinum      0
# Rhodium       0
# Nickel        0
# Tin           0
# Lithium       0
# Aluminum      0
# Carbon        0
# Profit ($)    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Item        10000 non-null  object
#  1   Category    10000 non-null  object
#  2   Gold        10000 non-null  float64
#  3   Silver      10000 non-null  float64
#  4   Platinum    10000 non-null  float64
#  5   Rhodium     10000 non-null  float64
#  6   Nickel      10000 non-null  float64
#  7   Tin         10000 non-null  float64
#  8   Lithium     10000 non-null  float64
#  9   Aluminum    10000 non-null  float64
#  10  Carbon      10000 non-null  float64
#  11  Profit ($)  10000 non-null  int64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 937.6+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                Gold        Silver      Platinum       Rhodium        Nickel  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       5.058206      5.001442      5.055381      5.086352      5.032354
# std        2.863858      2.855341      2.851408      2.838022      2.866194
# min        0.100000      0.100000      0.100000      0.100000      0.100000
# 25%        2.590000      2.530000      2.590000      2.640000      2.530000
# 50%        5.060000      4.970000      5.050000      5.110000      5.000000
# 75%        7.570000      7.470000      7.562500      7.530000      7.560000
# max       10.000000     10.000000     10.000000     10.000000     10.000000
#
#                 Tin       Lithium      Aluminum        Carbon    Profit ($)
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       5.023587      5.006292      5.001327      5.032132    521.949800
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Category'] = le.fit_transform(df['Category'])

# %%
df = df.drop("Item", axis=1)

# %%
import numpy as np

your_threshold_value = 500 # Example threshold, please define based on your analysis
df['Recovery_Status'] = np.where(df['Profit ($)'] > your_threshold_value, 'Recoverable', 'Non-recoverable')

df.head()
# Out:
#    Category  Gold  Silver  Platinum  Rhodium  Nickel   Tin  Lithium  Aluminum  \
# 0         2  3.58    2.95      1.73     8.92    1.91  1.01     1.82      1.27
# 1         1  7.21    4.31      6.21     5.63    9.59  7.65     0.51      3.03
# 2         3  8.91    5.09      2.42     7.70    1.09  1.49     7.42      3.63
# 3         1  2.62    3.84      2.98     7.66    9.41  2.25     7.84      6.18
# 4         0  3.47    3.89      6.20     4.35    5.07  8.65     8.62      0.82
#
#    Carbon  Profit ($)  Recovery_Status
# 0    9.51         270  Non-recoverable
# 1    4.22         689      Recoverable
# 2    8.83         570      Recoverable
# 3    6.36         290  Non-recoverable
# 4    5.53         505      Recoverable

# %%
df['Recyclable'] = (df['Profit ($)'] > 300).astype(int)

# %%
X = df.drop(['Profit ($)', 'Recyclable'], axis=1)
y = df['Recyclable']

# %%
 df['Recovery_Status'] = df['Recovery_Status'].map({
    'Recyclable': 1,
    'Non-Recyclable': 0
})

# %%
df['Recovery_Status'].unique()
# Out:
# array([nan])

# %%
df['Recovery_Status'].unique()
# Out:
# array([nan])

# %%
import pandas as pd
df = pd.read_csv("cleaned_ewaste_dataset.csv")

# %%
df['Recovery_Status'].unique()
# Out:
# array([0, 1])

# %%
df.isnull().sum()
# Out:
# Category           0
# Gold               0
# Silver             0
# Platinum           0
# Rhodium            0
# Nickel             0
# Tin                0
# Lithium            0
# Aluminum           0
# Carbon             0
# Profit ($)         0
# Recovery_Status    0
# Recyclable         0
# dtype: int64

# %%
X = df.drop('Recovery_Status', axis=1)
y = df['Recovery_Status']

# %%
df.head()
# Out:
#    Category  Gold  Silver  Platinum  Rhodium  Nickel   Tin  Lithium  Aluminum  \
# 0         2  3.58    2.95      1.73     8.92    1.91  1.01     1.82      1.27
# 1         1  7.21    4.31      6.21     5.63    9.59  7.65     0.51      3.03
# 2         3  8.91    5.09      2.42     7.70    1.09  1.49     7.42      3.63
# 3         1  2.62    3.84      2.98     7.66    9.41  2.25     7.84      6.18
# 4         0  3.47    3.89      6.20     4.35    5.07  8.65     8.62      0.82
#
#    Carbon  Profit ($)  Recovery_Status  Recyclable
# 0    9.51         270                0           0
# 1    4.22         689                1           1
# 2    8.83         570                1           1
# 3    6.36         290                0           0
# 4    5.53         505                1           1

# %%
df['Non_Recyclable'] = 1 - df['Recyclable']

# %%
df.head()
# Out:
#    Category  Gold  Silver  Platinum  Rhodium  Nickel   Tin  Lithium  Aluminum  \
# 0         2  3.58    2.95      1.73     8.92    1.91  1.01     1.82      1.27
# 1         1  7.21    4.31      6.21     5.63    9.59  7.65     0.51      3.03
# 2         3  8.91    5.09      2.42     7.70    1.09  1.49     7.42      3.63
# 3         1  2.62    3.84      2.98     7.66    9.41  2.25     7.84      6.18
# 4         0  3.47    3.89      6.20     4.35    5.07  8.65     8.62      0.82
#
#    Carbon  Profit ($)  Recovery_Status  Recyclable  Non_Recyclable
# 0    9.51         270                0           0               1
# 1    4.22         689                1           1               0
# 2    8.83         570                1           1               0
# 3    6.36         290                0           0               1
# 4    5.53         505                1           1               0

# %%
df['Recyclable'] = 1 - df['Recyclable']

# %%
df['Non_Recyclable'] = 1 - df['Recyclable']

# %%
df[['Recyclable','Non_Recyclable']].head()
# Out:
#    Recyclable  Non_Recyclable
# 0           1               0
# 1           0               1
# 2           0               1
# 3           1               0
# 4           0               1

# %%
df.head()
# Out:
#    Category  Gold  Silver  Platinum  Rhodium  Nickel   Tin  Lithium  Aluminum  \
# 0         2  3.58    2.95      1.73     8.92    1.91  1.01     1.82      1.27
# 1         1  7.21    4.31      6.21     5.63    9.59  7.65     0.51      3.03
# 2         3  8.91    5.09      2.42     7.70    1.09  1.49     7.42      3.63
# 3         1  2.62    3.84      2.98     7.66    9.41  2.25     7.84      6.18
# 4         0  3.47    3.89      6.20     4.35    5.07  8.65     8.62      0.82
#
#    Carbon  Profit ($)  Recovery_Status  Recyclable  Non_Recyclable
# 0    9.51         270                0           1               0
# 1    4.22         689                1           0               1
# 2    8.83         570                1           0               1
# 3    6.36         290                0           1               0
# 4    5.53         505                1           0               1

# %%
df.to_csv("ewaste_final_dataset.csv", index=False)

# %%
from google.colab import files
files.download("ewaste_final_dataset.csv")
